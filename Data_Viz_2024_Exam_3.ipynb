# %% [markdown]
# <a href="https://colab.research.google.com/github/punramon/python_dataviz2024/blob/main/Data_Viz_2024_Exam_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# จากข้อมูลที่ดึงจาก post ที่มีการแชร์เกี่ยวกับประสบการณ์โรคมะเร็งใน Facebook นี้
#
# https://drive.google.com/drive/folders/1vSm6imKOfZqw9Tx1i6GTdvukQbHDkLyf?usp=sharing
#
# ให้แสดงวิธีการจัดการข้อมูลและนำเสนอจุดที่น่าสนใจในข้อมูลนี้มา 2 จุด

# %% [markdown]
# ## import data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/MyDrive/Exam_last' #set path --> folder and then join path เพื่อให้โค้ดrunได้ทุกที่

docter_file_path = os.path.join(path,'Data_Docter_ศ.นพ.ชวลิต.csv')

# %%
print(docter_file_path)
# Out:
# /content/drive/MyDrive/Exam_last/Data_Docter_ศ.นพ.ชวลิต.csv

# %%
docter = pd.read_csv(docter_file_path)

# %%
docter
# Out:
#                                       name  \
# 0     ศ.นพ.ชวลิต ศูนย์มะเร็ง รพ.จุฬาลงกรณ์
# 1                           Nubeer Kithiya
# 2                          วาสนา คุ้มจิตต์
# 3                     Wansook Chompoo Ploy
# 4                              Aphit Aphit
# ...                                    ...
# 1648                           Fear Q'bick
# 1649                          Toei Nittiya
# 1650                       Ouiaii Promsuan
# 1651                      Thanyalak Banboo
# 1652                         Maii Mutchima
#
#                                                comments  ยอดไลค์  \
# 0     กดที่ลิงค์นี้เพื่อเข้าไปอ่านคอมเม้นของโพสต์ครั...      456
# 1     เป็นมะเร็งลำไส้ใหญ่ ระยะที่ 3 ตอนอายุ 26 ค่ะ พ...     1400
# 2     แม่เป็นมะเร็งขั้วปอด ลามขึ้นสมองค่ะ เริ่มแรกที...      402
# 3     #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอ...     1600
# 4     ลูกสาวเป็นมะเร็งกระดูก Osteosarcomaช่วงเข่า อา...      480
# ...

# %%
# Display the first few rows and basic info of the dataset
docter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1653 entries, 0 to 1652
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1653 non-null   object
#  1   comments         1653 non-null   object
#  2   ยอดไลค์          1653 non-null   int64
#  3   จำนวนการตอบกลับ  1653 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 51.8+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot to visualize the relationship between likes and replies
plt.figure(figsize=(10, 6))
sns.scatterplot(data=docter, x="ยอดไลค์", y="จำนวนการตอบกลับ")
plt.title("Relationship between Likes and Replies")
plt.xlabel("Number of Likes")
plt.ylabel("Number of Replies")
plt.grid(True)
plt.show()

# %%
# Calculating the correlation between Likes and Replies
correlation = docter['ยอดไลค์'].corr(docter['จำนวนการตอบกลับ'])
correlation
# Out:
# 0.7481607512108936

# %% [markdown]
# เมื่อความคิดเห็นได้รับไลค์มากขึ้น ก็มีแนวโน้มที่จะมีการตอบกลับมากขึ้นด้วย

# %%
# คัดเลือก 3 โพสต์ที่มีจำนวนไลค์สูงสุด
top_liked_posts = docter.nlargest(3, 'ยอดไลค์')

# แสดงผลลัพธ์: ชื่อผู้โพสต์, เนื้อหาความคิดเห็น, ยอดไลค์ และจำนวนการตอบกลับ
print("3 เรื่องที่คนสนใจมากที่สุด:")
for i, row in top_liked_posts.iterrows():
    print(f"\nเรื่องที่ {i + 1}:")
    print(f"ชื่อผู้โพสต์: {row['name']}")
    print(f"เนื้อหา: {row['comments']}")
    print(f"ยอดไลค์: {row['ยอดไลค์']}")
    print(f"จำนวนการตอบกลับ: {row['จำนวนการตอบกลับ']}")
# Out:
# 3 เรื่องที่คนสนใจมากที่สุด:
#
# เรื่องที่ 4:
# ชื่อผู้โพสต์: Wansook Chompoo Ploy
# เนื้อหา: #มะเร็งปากมดลูกระยะCINlll เกือบเข้าระยะ 1 ตอนอายุ 30... ตรวจpep.ทุกปี ไม่มีอะไรผิดปกติ วันดีคืนเดือด อยู่ๆภูมิแพ้ผิวหนังขึ้นทั้งวันทั้งคืน กินยายังไงก็ไม่ลง ทั้งๆที่ก่อนหน้านั้นก็รักษาภูมิแพ้ผิวหนังจนหายแล้ว เลยนึกขึ้นได้ว่า แพทย์ผิงหนังเคยเตือนว่า หากมีอาการภูมิแพ้แบบนี้อีก ให้ตรวจอย่างอื่นที่ผิดปกติร่วมด้วย ซึ่งมันคืออาการภูมิคุ้มกันบกพร่อง(ภูมิตก)แล้วแสดงสัญญาณทางผิวหนัง .... จึงไปตรวจpep.แบบคัดเชื้อhpvร่วมด้วย เพราะเป็นคน ปจด มาไม่ปกติตั้งแต่เด็กๆ ... สรุป นางมาจริง ทั้ง 16,18 ดุสุดทั้งคู่  ณ วันที่หมออ่านผลคือ CIN ll ระยะเวลารอทำcolpo. 1เดือน ผลcolpo. ขยับไป CIN lll หมอสั่งทำ Leep ทันที เพราะระยะเดินเร็วเกินไป แต่ก็ต้องรออีก1 เดือน เนื่องด้วยว่าคุณหมอคำนวนแล้วว่า น่าจะชนกัน ปจด ซึ่งอาจทำให้แผลหายช้าลงได้
# ยอดไลค์: 1600
# จำนวนการตอบกลับ: 44
#
# เรื่องที่ 6:
# ชื่อผู้โพสต์: Ize Atitya
# ...

# %%
# กำหนดคำที่เกี่ยวข้องกับการเสียชีวิต
death_keywords = ['ตาย','เสียชีวิต', 'จากไป', 'ไม่รอด', 'สิ้นใจ']

# กำหนดคำที่เกี่ยวข้องกับชนิดของมะเร็ง
cancer_keywords = {
    'มะเร็งปอด': 0,
    'มะเร็งเต้านม': 0,
    'มะเร็งตับ': 0,
    'มะเร็งลำไส้': 0,
    'มะเร็งกระดูก': 0,
    'มะเร็งปากมดลูก': 0,
    'มะเร็งต่อมลูกหมาก': 0,
    'มะเร็งผิวหนัง': 0,
    'มะเร็งกระเพาะอาหาร': 0,
    'มะเร็งเม็ดเลือดขาว': 0,
    'มะเร็งสมอง': 0,
    'มะเร็งรังไข่': 0,
    'มะเร็งต่อมไทรอยด์': 0,
    'มะเร็งต่อมน้ำเหลือง': 0,
    'มะเร็งกระเพาะปัสสาวะ': 0,
    'มะเร็งช่องปาก': 0,
    'มะเร็งหลอดอาหาร': 0
}

# ค้นหาและนับการกล่าวถึงมะเร็งชนิดต่างๆ ที่มีการกล่าวถึงการเสียชีวิต
for comment in docter['comments']:
    if any(keyword in comment for keyword in death_keywords):
        for cancer in cancer_keywords:
            if cancer in comment:
                cancer_keywords[cancer] += 1

# จัดเรียงข้อมูลตามจำนวนการกล่าวถึงจากมากไปน้อย
sorted_cancer_deaths = sorted(cancer_keywords.items(), key=lambda item: item[1], reverse=True)

# แสดงผลลัพธ์
top_cancer_deaths = sorted_cancer_deaths[:17]
print("ชนิดของมะเร็งที่มีการกล่าวถึงการเสียชีวิตมากที่สุด:")
for cancer, count in top_cancer_deaths:
    print(f"{cancer}: {count} ครั้ง")
# Out:
# ชนิดของมะเร็งที่มีการกล่าวถึงการเสียชีวิตมากที่สุด:
# มะเร็งตับ: 11 ครั้ง
# มะเร็งลำไส้: 3 ครั้ง
# มะเร็งปอด: 2 ครั้ง
# มะเร็งเต้านม: 2 ครั้ง
# มะเร็งกระเพาะอาหาร: 2 ครั้ง
# มะเร็งสมอง: 2 ครั้ง
# มะเร็งหลอดอาหาร: 2 ครั้ง
# มะเร็งกระดูก: 1 ครั้ง
# มะเร็งเม็ดเลือดขาว: 1 ครั้ง
# มะเร็งต่อมน้ำเหลือง: 1 ครั้ง
# มะเร็งปากมดลูก: 0 ครั้ง
# มะเร็งต่อมลูกหมาก: 0 ครั้ง
# มะเร็งผิวหนัง: 0 ครั้ง
# มะเร็งรังไข่: 0 ครั้ง
# มะเร็งต่อมไทรอยด์: 0 ครั้ง
# มะเร็งกระเพาะปัสสาวะ: 0 ครั้ง
# มะเร็งช่องปาก: 0 ครั้ง

# %%
# !wget -q https://github.com/google/fonts/raw/main/ofl/sarabun/Sarabun-Regular.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('Sarabun-Regular.ttf')
mpl.rc('font', family='Sarabun')

# %%
import matplotlib.pyplot as plt

# Extract cancer types and counts
cancer_types = [cancer for cancer, count in top_cancer_deaths]
death_counts = [count for cancer, count in top_cancer_deaths]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(cancer_types, death_counts)
plt.xlabel("Cancer Type")
plt.ylabel("Number of Mentions with Death Keywords")
plt.title("Top Cancer Types Mentioned with Death Keywords")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Keywords related to different types of cancer in Thai
cancer_keywords = ['มะเร็งปอด', 'มะเร็งเต้านม', 'มะเร็งตับ',
                   'มะเร็งลำไส้', 'มะเร็งกระดูก', 'มะเร็งปากมดลูก',
                   'มะเร็งต่อมลูกหมาก', 'มะเร็งผิวหนัง', 'มะเร็งกระเพาะอาหาร',
                   'มะเร็งเม็ดเลือดขาว', 'มะเร็งสมอง', 'มะเร็งรังไข่','มะเร็งต่อมไทรอยด์','มะเร็งตับ',
                   'มะเร็งต่อมน้ำเหลือง','มะเร็งกระเพาะปัสสาวะ','มะเร็งช่องปาก','มะเร็งหลอดอาหาร',
                   ]

# Create a dictionary to count occurrences of each cancer type
cancer_count = {cancer: 0 for cancer in cancer_keywords}

# Count occurrences of each cancer type in the comments
for comment in docter['comments']:
    for cancer in cancer_keywords:
        if cancer in comment:
            cancer_count[cancer] += 1

# Sort the results by the number of occurrences
sorted_cancer_count = sorted(cancer_count.items(), key=lambda item: item[1], reverse=True)
sorted_cancer_count
# Out:
# [('มะเร็งตับ', 128),
#  ('มะเร็งเต้านม', 64),
#  ('มะเร็งลำไส้', 55),
#  ('มะเร็งปอด', 52),
#  ('มะเร็งต่อมน้ำเหลือง', 40),
#  ('มะเร็งเม็ดเลือดขาว', 29),
#  ('มะเร็งปากมดลูก', 17),
#  ('มะเร็งรังไข่', 14),
#  ('มะเร็งกระดูก', 13),
#  ('มะเร็งต่อมลูกหมาก', 10),
#  ('มะเร็งสมอง', 9),
#  ('มะเร็งผิวหนัง', 5),
#  ('มะเร็งกระเพาะอาหาร', 5),
#  ('มะเร็งหลอดอาหาร', 4),
#  ('มะเร็งต่อมไทรอยด์', 2),
#  ('มะเร็งกระเพาะปัสสาวะ', 2),
#  ('มะเร็งช่องปาก', 2)]

# %%
#สร้างกราฟจาก sorted_cancer_count

# Extract cancer types and counts
cancer_types = [cancer for cancer, count in sorted_cancer_count]
cancer_counts = [count for cancer, count in sorted_cancer_count]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(cancer_types, cancer_counts)
plt.xlabel("Cancer Type")
plt.ylabel("Number of Mentions")
plt.title("Top Cancer Types Mentioned")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# กำหนดคำที่เกี่ยวข้องกับการเสียชีวิต
death_keywords = ['ตาย','เสียชีวิต', 'จากไป', 'ไม่รอด', 'สิ้นใจ', 'ล้มตาย']

# สร้างคอลัมน์ใหม่ที่บ่งบอกว่ามีการกล่าวถึงการเสียชีวิตหรือไม่
docter['เสียชีวิต'] = docter['comments'].apply(lambda x: any(keyword in x for keyword in death_keywords))

# กรองข้อมูลเพื่อแสดงเฉพาะโพสต์ที่มีการกล่าวถึงการเสียชีวิต
death_posts = docter[docter['เสียชีวิต'] == True]

# นับจำนวนโพสต์ที่มีการกล่าวถึงการเสียชีวิต
death_posts_count = len(death_posts)

# แสดงผลลัพธ์จำนวนโพสต์
print(f"จำนวนโพสต์ที่กล่าวถึงการเสียชีวิต: {death_posts_count}")

# แสดงโพสต์ที่กล่าวถึงการเสียชีวิต
print(death_posts[['name', 'comments', 'ยอดไลค์', 'จำนวนการตอบกลับ']])
# Out:
# จำนวนโพสต์ที่กล่าวถึงการเสียชีวิต: 43
#                                name  \
# 5                        Ize Atitya
# 10                    นู๋นิด ขนิษฐา
# 11                          Puy Puy
# 18                        Yani Insa
# 19                       WieWi Maka
# 30                   องุ่น รสสุคนธ์
# 45                  Nathi Pinthukas
# 120                 ปลายไง ปลายข้าว
# 127      Ratthakorn Santiparadonkul
# 128                 Ploy Ploypailin
# 131          ไพรัตน์ ชอบกินข้าวเช้า
# 158          Natsaran Siriweerakron
# 185                   Wahn Sunsiree
# 323                   พัชรี ณ รังษี
# 324                Sarunya Gumchart
# 342                      ลูก' เบนซ์
# 356             กัญญารัตน์ วิลัยกูล
# 361                 ธนวัน เจริญศิริ
# 385                            Nutt
# 403           Kingkan Suwannapakdee
# 406                     Newz Cubpom
# 421             Nilobon Pienmanakit
# 423                       Lalisa IP
# 431               Onnitcha Chuankid
# ...

# %%
death_posts[['name', 'comments', 'ยอดไลค์', 'จำนวนการตอบกลับ']]
# Out:
#                                name  \
# 5                        Ize Atitya
# 10                    นู๋นิด ขนิษฐา
# 11                          Puy Puy
# 18                        Yani Insa
# 19                       WieWi Maka
# 30                   องุ่น รสสุคนธ์
# 45                  Nathi Pinthukas
# 120                 ปลายไง ปลายข้าว
# 127      Ratthakorn Santiparadonkul
# 128                 Ploy Ploypailin
# 131          ไพรัตน์ ชอบกินข้าวเช้า
# 158          Natsaran Siriweerakron
# 185                   Wahn Sunsiree
# 323                   พัชรี ณ รังษี
# 324                Sarunya Gumchart
# 342                      ลูก' เบนซ์
# 356             กัญญารัตน์ วิลัยกูล
# 361                 ธนวัน เจริญศิริ
# 385                            Nutt
# 403           Kingkan Suwannapakdee
# 406                     Newz Cubpom
# 421             Nilobon Pienmanakit
# 423                       Lalisa IP
# 431               Onnitcha Chuankid
# 433                Jjoom Thammawong
# ...
