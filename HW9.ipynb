# %% [markdown]
# <a href="https://colab.research.google.com/github/punramon/python_dataviz2024/blob/main/HW9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW9 present radar chart data india

# %%
import pandas as pd

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_movie = '/content/drive/MyDrive/data_viz_2024_DATA/IMDb Movies India.csv'

# %%
data_india = pd.read_csv(path_to_movie, encoding='latin-1')
data_india
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
#ตรวจสอบค่า null
data_india.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
data_india = data_india.dropna(subset=['Rating', 'Votes','Duration','Genre', 'Director'])

# %%
data_india['Year'] =data_india['Year'].str.replace('(', '').str.replace(')', '').astype(int)
data_india['Duration'] = data_india['Duration'].str.replace(' min', '').astype(int)
data_india['Votes'] = data_india['Votes'].str.replace(',', '')
# Out:
# <ipython-input-19-d4b5746bc2e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_india['Year'] =data_india['Year'].str.replace('(', '').str.replace(')', '').astype(int)
# <ipython-input-19-d4b5746bc2e8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_india['Duration'] = data_india['Duration'].str.replace(' min', '').astype(int)
# <ipython-input-19-d4b5746bc2e8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_india['Votes'] = data_india['Votes'].str.replace(',', '')

# %%
# ตรวจสอบและแปลงคอลัมน์ Votes เป็น float
data_india['Votes'] = pd.to_numeric(data_india['Votes'], errors='coerce')
# Out:
# <ipython-input-20-19497a595d1c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_india['Votes'] = pd.to_numeric(data_india['Votes'], errors='coerce')

# %%
data_india
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# 6            Drama, Romance, War     7.4   1086   Shoojit Sircar
# 8      Horror, Mystery, Thriller     5.6    326    Allyson Patel
# ...                          ...     ...    ...              ...
# 15493                      Drama     6.1    408      Mozez Singh
# 15494  Biography, Drama, History     6.2   1496    Shyam Benegal
# 15503       Action, Crime, Drama     5.8     44  S.P. Muthuraman
# 15505              Action, Drama     4.5    655       Kuku Kohli
# 15508              Action, Drama     6.2     20     K.C. Bokadia
#
#                Actor 1                 Actor 2           Actor 3
# 1         Rasika Dugal          Vivek Ghamande     Arvind Jangid
# 3              Prateik              Ishita Raj   Siddhant Kapoor
# 5           Bobby Deol  Aishwarya Rai Bachchan     Shammi Kapoor
# 6      Jimmy Sheirgill          Minissha Lamba    Yashpal Sharma
# 8            Yash Dave          Muntazir Ahmad      Kiran Bhatia
# ...                ...                     ...               ...
# 15493    Vicky Kaushal         Sarah Jane Dias  Raaghavv Chanana
# 15494   Karisma Kapoor                   Rekha    Manoj Bajpayee
# 15503      Chiranjeevi              Jayamalini       Rajinikanth
# 15505     Akshay Kumar          Twinkle Khanna       Aruna Irani
# 15508       Dharmendra              Jaya Prada       Arjun Sarja
#
# [5819 rows x 10 columns]

# %%
#หลังdropnaแล้วข้อมูลเหลือกี่%จากเดิม

print(f"ข้อมูลเหลือ {(len(data_india) / len(pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/IMDb Movies India.csv', encoding='latin-1'))) * 100:.2f}% จากเดิม")
# Out:
# ข้อมูลเหลือ 37.52% จากเดิม

# %%
data_india.isnull().sum()
# Out:
# Name          0
# Year          0
# Duration      0
# Genre         0
# Rating        0
# Votes         0
# Director      0
# Actor 1      73
# Actor 2     114
# Actor 3     160
# dtype: int64

# %%
# prompt: split value in column genre by ',' and make more column for each of those

import pandas as pd
# Split the 'Genre' column by ',' and create new columns
genre_split = data_india['Genre'].str.split(',', expand=True)

# Rename the new columns
genre_split.columns = ['Genre1', 'Genre2', 'Genre3']

# Concatenate the new columns with the original DataFrame
data_india = pd.concat([data_india, genre_split], axis=1)

# Display the updated DataFrame
data_india.head()
# Out:
#                                  Name  Year  Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019       109
# 3                             #Yaaram  2019       110
# 5                ...Aur Pyaar Ho Gaya  1997       147
# 6                           ...Yahaan  2005       142
# 8                  ?: A Question Mark  2012        82
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4   1086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3  Genre1    Genre2     Genre3
# 1          Vivek Ghamande    Arvind Jangid   Drama      None       None
# 3              Ishita Raj  Siddhant Kapoor  Comedy   Romance       None
# 5  Aishwarya Rai Bachchan    Shammi Kapoor  Comedy     Drama    Musical
# 6          Minissha Lamba   Yashpal Sharma   Drama   Romance        War
# 8          Muntazir Ahmad     Kiran Bhatia  Horror   Mystery   Thriller

# %%
# prompt: delete space in the value in Genre1 Genre2 Genre3

for col in ['Genre1', 'Genre2', 'Genre3']:
  data_india[col] = data_india[col].str.strip() if data_india[col].dtype == 'object' else data_india[col]

# %%
data_india
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# 6            Drama, Romance, War     7.4   1086   Shoojit Sircar
# 8      Horror, Mystery, Thriller     5.6    326    Allyson Patel
# ...                          ...     ...    ...              ...
# 15493                      Drama     6.1    408      Mozez Singh
# 15494  Biography, Drama, History     6.2   1496    Shyam Benegal
# 15503       Action, Crime, Drama     5.8     44  S.P. Muthuraman
# 15505              Action, Drama     4.5    655       Kuku Kohli
# 15508              Action, Drama     6.2     20     K.C. Bokadia
#
#                Actor 1                 Actor 2           Actor 3     Genre1  \
# 1         Rasika Dugal          Vivek Ghamande     Arvind Jangid      Drama
# 3              Prateik              Ishita Raj   Siddhant Kapoor     Comedy
# 5           Bobby Deol  Aishwarya Rai Bachchan     Shammi Kapoor     Comedy
# 6      Jimmy Sheirgill          Minissha Lamba    Yashpal Sharma      Drama
# 8            Yash Dave          Muntazir Ahmad      Kiran Bhatia     Horror
# ...                ...                     ...               ...        ...
# 15493    Vicky Kaushal         Sarah Jane Dias  Raaghavv Chanana      Drama
# 15494   Karisma Kapoor                   Rekha    Manoj Bajpayee  Biography
# 15503      Chiranjeevi              Jayamalini       Rajinikanth     Action
# 15505     Akshay Kumar          Twinkle Khanna       Aruna Irani     Action
# 15508       Dharmendra              Jaya Prada       Arjun Sarja     Action
#
#         Genre2    Genre3
# 1         None      None
# 3      Romance      None
# 5        Drama   Musical
# 6      Romance       War
# 8      Mystery  Thriller
# ...        ...       ...
# 15493     None      None
# 15494    Drama   History
# 15503    Crime     Drama
# 15505    Drama      None
# 15508    Drama      None
#
# [5819 rows x 13 columns]

# %%
# prompt: เลือกผู้กำกับที่มี Rating และ Votes มากกว่า 75%
# top_directors = movie_df[(movie_df['Rating'] >= rating_q3) & (movie_df['Votes'] >= tes_q3)]['Director'].value_counts() และ คิดเกณฑ์คะแนนถ่วงน้ำหนัก Votes และ rating ให้ rating 60% และ Votes 40% ถ่วงให้ไม่เกิน 100%
# Calculate the 75th percentile for Rating and Votes
rating_q3 = data_india['Rating'].quantile(0.75)
tes_q3 = data_india['Votes'].quantile(0.75)

# Filter the DataFrame to include only directors with Rating and Votes above the 75th percentile
top_directors = data_india[(data_india['Rating'] >= rating_q3) & (data_india['Votes'] >= tes_q3)]['Director'].value_counts()
top_directors
# Out:
# Director
# Yash Chopra             11
# Hrishikesh Mukherjee    10
# Anurag Kashyap           9
# Ram Gopal Varma          8
# Nagesh Kukunoor          8
#                         ..
# Aatish Kapadia           1
# Faruk Kabir              1
# Rakesh Roshan            1
# Manoj Kumar              1
# Milind Dhaimade          1
# Name: count, Length: 288, dtype: int64

# %%
top_directors.head(10)
# Out:
# Director
# Yash Chopra              11
# Hrishikesh Mukherjee     10
# Anurag Kashyap            9
# Ram Gopal Varma           8
# Nagesh Kukunoor           8
# Vishal Bhardwaj           7
# Sanjay Leela Bhansali     7
# Raj Kapoor                7
# Priyadarshan              7
# Gulzar                    6
# Name: count, dtype: int64

# %%
# ไว้ทดเช็คข้อมูล
data_india[data_india['Director'] == 'Hrishikesh Mukherjee']
# %%
# prompt: ดึงข้อมูลของ Yash Chopra, Ram Gopal Varma, Hrishikesh Mukherjee, Anurag Kashyap, Nagesh Kukunoor มาเป็นdataframeใหม่

directors_to_extract = ['Yash Chopra', 'Ram Gopal Varma', 'Hrishikesh Mukherjee', 'Anurag Kashyap', 'Nagesh Kukunoor']
top = data_india[data_india['Director'].isin(directors_to_extract)].copy()
top
# Out:
#                    Name  Year  Duration                     Genre  Rating  \
# 22           12 O'Clock  2021       105          Horror, Thriller     4.4
# 73          3 Deewarein  2003       115              Crime, Drama     7.8
# 125      8 x 10 Tasveer  2009       122  Action, Fantasy, Mystery     5.4
# 216    Aadmi Aur Insaan  1969       168  Drama, Romance, Thriller     6.2
# 475           Aashayein  2010       120                     Drama     7.1
# ...                 ...   ...       ...                       ...     ...
# 14582              Ugly  2013       128     Crime, Drama, Mystery     8.0
# 14816         Veerappan  2016       125  Action, Biography, Crime     5.3
# 14826        Veer-Zaara  2004       192    Drama, Family, Musical     7.8
# 14864             Vijay  1988       172    Action, Drama, Romance     5.6
# 14983              Waqt  1965       178            Drama, Romance     7.8
#
#        Votes         Director             Actor 1            Actor 2  \
# 22        63  Ram Gopal Varma  Mithun Chakraborty  Makrand Deshpande
# 73      2322  Nagesh Kukunoor    Naseeruddin Shah      Jackie Shroff
# 125     5459  Nagesh Kukunoor        Akshay Kumar       Ayesha Takia
# 216      149      Yash Chopra          Dharmendra         Saira Banu
# 475     1259  Nagesh Kukunoor        John Abraham       Anaitha Nair
# ...      ...              ...                 ...                ...
# 14582  20709   Anurag Kashyap         Rahul Bhatt          Ronit Roy
# 14816    711  Ram Gopal Varma       Sachiin Joshi  Sandeep Bharadwaj
# 14826  50101      Yash Chopra      Shah Rukh Khan       Preity Zinta
# 14864    219      Yash Chopra         Anil Kapoor      Rajesh Khanna
# 14983   1244      Yash Chopra          Sunil Dutt            Sadhana
#
#                    Actor 3  Genre1     Genre2    Genre3
# 22             Dalip Tahil  Horror   Thriller      None
# 73             Juhi Chawla   Crime      Drama      None
# 125          Javed Jaffrey  Action    Fantasy   Mystery
# 216             Feroz Khan   Drama    Romance  Thriller
# 475          Girish Karnad   Drama       None      None
# ...                    ...     ...        ...       ...
# 14582  Tejaswini Kolhapure   Crime      Drama   Mystery
# 14816          Usha Jadhav  Action  Biography     Crime
# 14826         Rani Mukerji   Drama     Family   Musical
# 14864         Rishi Kapoor  Action      Drama   Romance
# 14983           Raaj Kumar   Drama    Romance      None
#
# [114 rows x 13 columns]

# %%
# ทดดูภาพรวม Genre
# prompt: Using dataframe top: สร้าง bar  นับจำนวน Genre1  Genre2  Genre3 ของ director ใช้ px

import plotly.express as px

# Group by director and count the number of each genre
genre_counts = top.groupby(['Director', 'Genre1'])['Name'].count().reset_index(name='Count')
genre_counts2 = top.groupby(['Director', 'Genre2'])['Name'].count().reset_index(name='Count')
genre_counts3 = top.groupby(['Director', 'Genre3'])['Name'].count().reset_index(name='Count')

# Create a bar chart using Plotly Express
fig = px.bar(genre_counts, x='Director', y='Count', color='Genre1', barmode='group', title='Genre1 Count by Director')
fig.show()

fig2 = px.bar(genre_counts2, x='Director', y='Count', color='Genre2', barmode='group', title='Genre2 Count by Director')
fig2.show()

fig3 = px.bar(genre_counts3, x='Director', y='Count', color='Genre3', barmode='group', title='Genre3 Count by Director')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1
...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3bbc0536-f9d0-4ae7-82a6-e18ca7e58fc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bbc0536-f9d0-4ae7-82a6-e18ca7e58fc2")) {                    Plotly.newPlot(                        "3bbc0536-f9d0-4ae7-82a6-e18ca7e58fc2",                        [{"alignmentgroup":"True","hovertemplate":"Genre3=Adventure\u003cbr\u003eDirector=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adventure","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Adventure","offsetgroup":"Adventure","orientation":"v","showlegend":true,"textposition":"auto","x":["Anurag Kashyap"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Genre3=Crime\u003cbr\u003eDirector=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Crime","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Crime","offsetgroup":"Crime","orientation":"v","showlegend":true,"textposition":"auto","x":["Anurag Kashyap","Ram Gopal Varma"],"xaxis":"x","y":[1,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Genre3=Drama\u003cbr\u003eDirector=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Drama","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Drama","offsetgroup":"Drama","orientation":"v","showlegend":true,"textposition":"auto","x":["Anurag Kashyap","Hrishikesh Mukherjee","Ram Gopal Varma","Yash Chopra"],"xaxis":"x","y":[2,2,11,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Genre3=Mystery\u003cbr\u003eDirector=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mystery","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Mystery","offsetgroup":"Mystery","orientation":"v","showlegend":true,"textposition":"auto","x":["Anurag Kashyap","Nagesh Kukunoor","Ram Gopal Varma"],"xaxis":"x","y":[3,1,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Genre3=Romance\u003cbr\u003eDirector=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Romance","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Romance","offsetgroup":"Romance","orientation":"v","showlegend":true,"textposition":"auto","x":["Anurag Kashyap","Hrishikesh Mukherjee","Nagesh Kukunoor","Ram Gopal Varma","Yash Chopra"],"xaxis":"x","y":[1,2,2,4,7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Genre3=Sport\u003cbr\u003eDirector=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sport","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Sport","offsetgroup":"Sport","orientation":"v","showlegend":true,"textposition":"auto","x":["Anurag Kashyap"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Genre3=Thriller\u003cbr\u003eDirector=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thriller","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Thriller","offsetgroup":"Thriller","orientation":"v","showlegend":true,"textposition":"auto","x":["Anurag Kashyap","Nagesh Kukunoor","Ram Gopal Varma","Yash Chopra"],"xaxis":"x","y":[2,1,7,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Genre3=Family\u003cbr\u003eDirector=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Family","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Family","offsetgroup":"Family","orientation":"v","showlegend":true,"textposition":"auto","x":["Hrishikesh Mukherjee","Yash Chopra"],"xaxis":"x","y":[4,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","h ...

# %%
# Assuming you want to plot a radar chart showing the count of movies directed by each director.
import plotly.express as px

# Group by 'Director' and count the number of movies directed by each.
director_counts = top.groupby('Director')['Name'].count().reset_index()

# Create the radar chart using Plotly Express.
fig = px.line_polar(director_counts, r='Name', theta='Director', line_close=True)

# Add title and fill the radar chart
fig.update_traces(fill='toself')
fig.update_layout(
    title="Number of Movies Directed by Each Director"  # Add the title here
)

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d1434b73-67ad-4234-a73b-61e23dc15aa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1434b73-67ad-4234-a73b-61e23dc15aa6")) {                    Plotly.newPlot(                        "d1434b73-67ad-4234-a73b-61e23dc15aa6",                        [{"hovertemplate":"Name=%{r}\u003cbr\u003eDirector=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","r":[14,33,11,34,22,14],"showlegend":false,"subplot":"polar","theta":["Anurag Kashyap","Hrishikesh Mukherjee","Nagesh Kukunoor","Ram Gopal Varma","Yash Chopra","Anurag Kashyap"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"sca ...

# %%
director_counts
# Out:
#                Director  Name
# 0        Anurag Kashyap    14
# 1  Hrishikesh Mukherjee    33
# 2       Nagesh Kukunoor    11
# 3       Ram Gopal Varma    34
# 4           Yash Chopra    22

# %%
# Group by 'Director' and calculate the average 'Votes' for each.
director_votes = top.groupby('Director')['Votes'].mean().reset_index()

# Create the radar chart using Plotly Express.
fig = px.line_polar(director_votes, r='Votes', theta='Director', line_close=True)

# Add title and fill the radar chart.
fig.update_traces(fill='toself')
fig.update_layout(
    title="Average Votes for Movies Directed by Each Director"  # Add the title here
)

# Show the chart.
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ac4daea-11ef-4d8b-8d3f-36388de0fbf6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ac4daea-11ef-4d8b-8d3f-36388de0fbf6")) {                    Plotly.newPlot(                        "0ac4daea-11ef-4d8b-8d3f-36388de0fbf6",                        [{"hovertemplate":"Votes=%{r}\u003cbr\u003eDirector=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","r":[15837.5,2463.5757575757575,3568.4545454545455,3190.5588235294117,7947.5,15837.5],"showlegend":false,"subplot":"polar","theta":["Anurag Kashyap","Hrishikesh Mukherjee","Nagesh Kukunoor","Ram Gopal Varma","Yash Chopra","Anurag Kashyap"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size ...

# %%
director_votes
# Out:
#                Director         Votes
# 0        Anurag Kashyap  15837.500000
# 1  Hrishikesh Mukherjee   2463.575758
# 2       Nagesh Kukunoor   3568.454545
# 3       Ram Gopal Varma   3190.558824
# 4           Yash Chopra   7947.500000

# %%
# Group by 'Director' and calculate the average 'Rating' for each.
director_Rating = top.groupby('Director')['Rating'].mean().reset_index()

# Create the radar chart using Plotly Express.
fig = px.line_polar(director_Rating, r='Rating', theta='Director', line_close=True)

# Add title and fill the radar chart.
fig.update_traces(fill='toself')
fig.update_layout(
    title="Average Rating for Movies Directed by Each Director"  # Add the title here
)

# Show the chart.
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5a8773aa-bf8d-4fbc-83ec-f5af4419020c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a8773aa-bf8d-4fbc-83ec-f5af4419020c")) {                    Plotly.newPlot(                        "5a8773aa-bf8d-4fbc-83ec-f5af4419020c",                        [{"hovertemplate":"Rating=%{r}\u003cbr\u003eDirector=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","r":[7.385714285714286,7.266666666666667,7.072727272727272,5.491176470588235,6.972727272727273,7.385714285714286],"showlegend":false,"subplot":"polar","theta":["Anurag Kashyap","Hrishikesh Mukherjee","Nagesh Kukunoor","Ram Gopal Varma","Yash Chopra","Anurag Kashyap"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern ...

# %%
director_Rating
# Out:
#                Director    Rating
# 0        Anurag Kashyap  7.385714
# 1  Hrishikesh Mukherjee  7.266667
# 2       Nagesh Kukunoor  7.072727
# 3       Ram Gopal Varma  5.491176
# 4           Yash Chopra  6.972727

# %%
# Group by 'Director' and calculate the average 'Duration' for each.
director_Duration = top.groupby('Director')['Duration'].mean().reset_index()

# Create the radar chart using Plotly Express.
fig = px.line_polar(director_Duration, r='Duration', theta='Director', line_close=True)

# Add title and fill the radar chart.
fig.update_traces(fill='toself')
fig.update_layout(
    title="Average Duration of Movies Directed by Each Director"  # Add the title here
)

# Show the chart.
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="29d30894-ce1b-4abe-8044-1b3fe9c28ce2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29d30894-ce1b-4abe-8044-1b3fe9c28ce2")) {                    Plotly.newPlot(                        "29d30894-ce1b-4abe-8044-1b3fe9c28ce2",                        [{"hovertemplate":"Duration=%{r}\u003cbr\u003eDirector=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","r":[146.64285714285714,142.06060606060606,114.9090909090909,128.76470588235293,165.72727272727272,146.64285714285714],"showlegend":false,"subplot":"polar","theta":["Anurag Kashyap","Hrishikesh Mukherjee","Nagesh Kukunoor","Ram Gopal Varma","Yash Chopra","Anurag Kashyap"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}," ...

# %%
director_Duration
# Out:
#                Director    Duration
# 0        Anurag Kashyap  146.642857
# 1  Hrishikesh Mukherjee  142.060606
# 2       Nagesh Kukunoor  114.909091
# 3       Ram Gopal Varma  128.764706
# 4           Yash Chopra  165.727273

# %%
top
# Out:
#                    Name  Year  Duration                     Genre  Rating  \
# 22           12 O'Clock  2021       105          Horror, Thriller     4.4
# 73          3 Deewarein  2003       115              Crime, Drama     7.8
# 125      8 x 10 Tasveer  2009       122  Action, Fantasy, Mystery     5.4
# 216    Aadmi Aur Insaan  1969       168  Drama, Romance, Thriller     6.2
# 475           Aashayein  2010       120                     Drama     7.1
# ...                 ...   ...       ...                       ...     ...
# 14582              Ugly  2013       128     Crime, Drama, Mystery     8.0
# 14816         Veerappan  2016       125  Action, Biography, Crime     5.3
# 14826        Veer-Zaara  2004       192    Drama, Family, Musical     7.8
# 14864             Vijay  1988       172    Action, Drama, Romance     5.6
# 14983              Waqt  1965       178            Drama, Romance     7.8
#
#        Votes         Director             Actor 1            Actor 2  \
# 22        63  Ram Gopal Varma  Mithun Chakraborty  Makrand Deshpande
# 73      2322  Nagesh Kukunoor    Naseeruddin Shah      Jackie Shroff
# 125     5459  Nagesh Kukunoor        Akshay Kumar       Ayesha Takia
# 216      149      Yash Chopra          Dharmendra         Saira Banu
# 475     1259  Nagesh Kukunoor        John Abraham       Anaitha Nair
# ...      ...              ...                 ...                ...
# 14582  20709   Anurag Kashyap         Rahul Bhatt          Ronit Roy
# 14816    711  Ram Gopal Varma       Sachiin Joshi  Sandeep Bharadwaj
# 14826  50101      Yash Chopra      Shah Rukh Khan       Preity Zinta
# 14864    219      Yash Chopra         Anil Kapoor      Rajesh Khanna
# 14983   1244      Yash Chopra          Sunil Dutt            Sadhana
#
#                    Actor 3  Genre1     Genre2    Genre3
# 22             Dalip Tahil  Horror   Thriller      None
# 73             Juhi Chawla   Crime      Drama      None
# 125          Javed Jaffrey  Action    Fantasy   Mystery
# 216             Feroz Khan   Drama    Romance  Thriller
# 475          Girish Karnad   Drama       None      None
# ...                    ...     ...        ...       ...
# 14582  Tejaswini Kolhapure   Crime      Drama   Mystery
# 14816          Usha Jadhav  Action  Biography     Crime
# 14826         Rani Mukerji   Drama     Family   Musical
# 14864         Rishi Kapoor  Action      Drama   Romance
# 14983           Raaj Kumar   Drama    Romance      None
#
# [114 rows x 13 columns]

# %%
allindiagenre = list(data_india['Genre1'])+list(data_india['Genre2'])+list(data_india['Genre3'])
allindiagenre
# Out:
# ['Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Action',
#  'Drama',
#  'Horror',
#  'Horror',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Crime',
#  'Horror',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Horror',
#  'Horror',
#  'Drama',
#  'Horror',
#  'Action',
#  'Action',
#  'Thriller',
#  'Comedy',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Comedy',
#  'Thriller',
#  'Drama',
#  'Sport',
#  'Biography',
#  'Drama',
#  'Horror',
#  'Comedy',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Horror',
#  'Horror',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Action',
#  'Horror',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Action',
#  'Adventure',
#  'Mystery',
#  'Action',
#  'Comedy',
#  'Musical',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Horror',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Romance',
#  'Documentary',
#  'Thriller',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Action',
#  'Musical',
#  'Drama',
#  'Action',
#  'Action',
#  'Mystery',
#  'Action',
#  'Drama',
#  'Fantasy',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Fantasy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Crime',
#  'Musical',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Crime',
#  'Action',
#  'Sci-Fi',
#  'Action',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Romance',
#  'Action',
#  'Action',
#  'Action',
#  'Thriller',
#  'Drama',
#  'Horror',
#  'Drama',
#  'Musical',
#  'Family',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Action',
#  'Drama',
#  'Romance',
#  'Musical',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Action',
#  'Action',
#  'Musical',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Action',
#  'Romance',
#  'Drama',
#  'Action',
#  'Action',
#  'Fantasy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Action',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Crime',
#  'Action',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Action',
#  'Action',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Action',
#  'Biography',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Adventure',
#  'Action',
#  'Action',
#  'Documentary',
#  'Drama',
#  'Action',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Action',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Crime',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Musical',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Musical',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Romance',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Action',
#  'Action',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Family',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Action',
#  'Drama',
#  'Fantasy',
#  'Biography',
#  'Comedy',
#  'Thriller',
#  'Action',
#  'Action',
#  'Action',
#  'Comedy',
#  'Action',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Drama',
#  'Musical',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Horror',
#  'Family',
#  'Action',
#  'Mystery',
#  'Comedy',
#  'Action',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Musical',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Musical',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'History',
#  'Crime',
#  'Drama',
#  'Musical',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Crime',
#  'Crime',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Musical',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Biography',
#  'Action',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'History',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Action',
#  'Mystery',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Biography',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Comedy',
#  'Animation',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Animation',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Action',
#  'Action',
#  'Musical',
#  'Drama',
#  'Action',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Action',
#  'Animation',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Family',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Crime',
#  'Drama',
#  'Action',
#  'Drama',
#  'Adventure',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Romance',
#  'Action',
#  'Documentary',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Biography',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Family',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Mystery',
#  'Action',
#  'Mystery',
#  'Crime',
#  'Crime',
#  'Crime',
#  'Action',
#  'Action',
#  'Crime',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Family',
#  'Thriller',
#  'Comedy',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Action',
#  'Action',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Family',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Comedy',
#  'Action',
#  'Fantasy',
#  'Action',
#  'Action',
#  'Animation',
#  'Animation',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Fantasy',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Romance',
#  'Musical',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Family',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Biography',
#  'Crime',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Musical',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'Action',
#  'Action',
#  'Mystery',
#  'Drama',
#  'Action',
#  'Romance',
#  'Drama',
#  'Musical',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  'Comedy',
#  'War',
#  'Drama',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Action',
#  'Action',
#  'Drama',
#  'Family',
#  'Drama',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Thriller',
#  'Comedy',
#  'Musical',
#  'Documentary',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Musical',
#  'Action',
#  'Biography',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Action',
#  'Action',
#  'Animation',
#  'Family',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Drama',
#  'Horror',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Comedy',
#  'Horror',
#  'Horror',
#  'Horror',
#  'Romance',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Horror',
#  'Animation',
#  'Comedy',
#  'Horror',
#  'Horror',
#  'Horror',
#  'Comedy',
#  'Comedy',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Documentary',
#  'Action',
#  'Action',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Adventure',
#  'Romance',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Romance',
#  'Action',
#  'History',
#  'Drama',
#  'Action',
#  'Action',
#  'Biography',
#  'Drama',
#  'Thriller',
#  'Documentary',
#  'Action',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Animation',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Action',
#  'Drama',
#  'Crime',
#  'Action',
#  'Comedy',
#  'Action',
#  'Action',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Documentary',
#  'Comedy',
#  'Action',
#  ...]

# %%
allgenre = list(top['Genre1'])+list(top['Genre2'])+list(top['Genre3'])
allgenre
# Out:
# ['Horror',
#  'Crime',
#  'Action',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Action',
#  'Musical',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Crime',
#  'Crime',
#  'Action',
#  'Romance',
#  'Drama',
#  'Crime',
#  'Comedy',
#  'Horror',
#  'Comedy',
#  'Action',
#  'Action',
#  'Action',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Action',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'Crime',
#  'Action',
#  'Action',
#  'Action',
#  'Crime',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Fantasy',
#  'Romance',
#  None,
#  None,
#  None,
#  'Musical',
#  'Horror',
#  'Musical',
#  'Musical',
#  'Drama',
#  'Romance',
#  'Romance',
#  'Musical',
#  'Musical',
#  'Family',
#  'Mystery',
#  'Mystery',
#  None,
#  'Crime',
#  'Crime',
#  'Crime',
#  'Mystery',
#  'Musical',
#  'Romance',
#  None,
#  'Drama',
#  'Horror',
#  'Crime',
#  'Crime',
#  'Crime',
#  'Music',
#  'Horror',
#  'Drama',
#  'Adventure',
#  'Crime',
#  'Crime',
#  'Romance',
#  None,
#  None,
#  'Drama',
#  None,
#  'Romance',
#  'Comedy',
#  'Crime',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Sport',
#  'Mystery',
#  'Romance',
#  'Romance',
#  None,
#  'Thriller',
#  'Adventure',
#  'Romance',
#  'Drama',
#  'Romance',
#  'Thriller',
#  'Drama',
#  'Romance',
#  None,
#  'Musical',
#  None,
#  'Drama',
#  'Musical',
#  'Drama',
#  'Romance',
#  'Romance',
#  None,
#  'Musical',
#  None,
#  'Drama',
#  None,
#  'Horror',
#  'Drama',
#  'Thriller',
#  'Drama',
#  None,
#  'Horror',
#  'Drama',
#  'Drama',
#  None,
#  'Drama',
#  'Biography',
#  'Biography',
#  'Adventure',
#  None,
#  'Drama',
#  'Mystery',
#  'Action',
#  'Drama',
#  'Family',
#  'Crime',
#  'Crime',
#  'Crime',
#  'Crime',
#  'Crime',
#  None,
#  'Crime',
#  'Crime',
#  'Family',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Biography',
#  'Family',
#  'Drama',
#  'Romance',
#  None,
#  None,
#  'Mystery',
#  'Thriller',
#  None,
#  None,
#  None,
#  None,
#  'Mystery',
#  None,
#  None,
#  'Musical',
#  None,
#  None,
#  'Romance',
#  'Drama',
#  None,
#  'Thriller',
#  'Thriller',
#  None,
#  'Drama',
#  'Romance',
#  'Drama',
#  'Drama',
#  'Romance',
#  None,
#  None,
#  'Romance',
#  'Thriller',
#  'Drama',
#  'Drama',
#  'Thriller',
#  'Romance',
#  'Romance',
#  'Romance',
#  'Comedy',
#  'Drama',
#  'Thriller',
#  None,
#  None,
#  None,
#  'Musical',
#  None,
#  None,
#  'Crime',
#  'Drama',
#  'Family',
#  'Thriller',
#  None,
#  'Romance',
#  'Romance',
#  None,
#  'Thriller',
#  None,
#  None,
#  None,
#  None,
#  'Romance',
#  None,
#  'History',
#  None,
#  None,
#  'Family',
#  None,
#  None,
#  'Romance',
#  None,
#  'Family',
#  'Romance',
#  None,
#  'Family',
#  'Thriller',
#  None,
#  'Romance',
#  None,
#  None,
#  None,
#  'Mystery',
#  'Thriller',
#  None,
#  'Romance',
#  None,
#  'Mystery',
#  'Thriller',
#  'Family',
#  None,
#  None,
#  'Crime',
#  'Crime',
#  'Comedy',
#  None,
#  'Musical',
#  'Thriller',
#  'Adventure',
#  None,
#  None,
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Drama',
#  None,
#  'Drama',
#  'Drama',
#  'Romance',
#  'Mystery',
#  'Drama',
#  'Sport',
#  'Musical',
#  'Mystery',
#  'Crime',
#  'Musical',
#  'Romance',
#  None]

# %%
unique_genres = list(set([genre for genre in allindiagenre if genre is not None]))
print(unique_genres)
# Out:
# ['Romance', 'Fantasy', 'News', 'Horror', 'Crime', 'Documentary', 'Musical', 'War', 'Western', 'Animation', 'Adventure', 'Action', 'Sci-Fi', 'Music', 'Thriller', 'Family', 'Sport', 'Comedy', 'Mystery', 'History', 'Biography', 'Drama']

# %%
# prompt: allgenreที่ไม่ซ้ำ

unique_genres = list(set([genre for genre in allgenre if genre is not None]))
print(unique_genres)
# Out:
# ['Romance', 'Musical', 'Adventure', 'Action', 'Comedy', 'Fantasy', 'Music', 'Mystery', 'Horror', 'Crime', 'History', 'Thriller', 'Family', 'Biography', 'Sport', 'Animation', 'Drama']

# %%
len(set(allindiagenre))
# Out:
# 23

# %%
len(set(allgenre))
# Out:
# 18

# %%
import pandas as pd
import plotly.graph_objects as go

# เตรียมข้อมูล
df = pd.DataFrame(top)

# รายการแนวหนังที่ต้องการพิจารณา
allgenre = df[['Genre1', 'Genre2', 'Genre3']].values.flatten().tolist()
unique_genres = list(set([genre for genre in allgenre if genre != '' and genre is not None]))

# คำนวณจำนวนหนังในแต่ละ Genre ที่ผู้กำกับแต่ละคนทำ
director_genre_count = {director: {genre: 0 for genre in unique_genres} for director in df['Director'].unique()}

# นับจำนวนหนังของผู้กำกับแต่ละคนในแต่ละ Genre
for _, row in df.iterrows():
    movie_genres = {row['Genre1'], row['Genre2'], row['Genre3']}
    movie_genres = {g for g in movie_genres if g != ''}  # เอา genre ที่ไม่ว่าง

    director = row['Director']
    for genre in movie_genres:
        if genre in director_genre_count[director]:
            director_genre_count[director][genre] += 1

# เลือกผู้กำกับที่ต้องการเปรียบเทียบ
selected_directors = df['Director'].unique()[:5]

# เตรียมข้อมูลสำหรับ Radar Chart
categories = unique_genres

# สร้างกราฟ Radar แบบโต้ตอบ
fig = go.Figure()

for director in selected_directors:
    values = list(director_genre_count[director].values())
    values += values[:1]  # ทำให้กราฟปิดวงกลม

    fig.add_trace(go.Scatterpolar(
        r=values,
        theta=categories + [categories[0]],  # เพื่อปิดกราฟ
        fill='toself',
        name=director
    ))

# ตั้งค่า layout
fig.update_layout(
    polar=dict(
        radialaxis=dict(visible=True, range=[0, max(max(director_genre_count[director].values()) for director in selected_directors)])
    ),
    title="Comparison of Movie Genres for Selected Directors",
    showlegend=True
)

# แสดงกราฟ
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c39700bc-45ce-466a-8401-be7f51a527e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c39700bc-45ce-466a-8401-be7f51a527e5")) {                    Plotly.newPlot(                        "c39700bc-45ce-466a-8401-be7f51a527e5",                        [{"fill":"toself","name":"Ram Gopal Varma","r":[4,3,3,20,0,4,0,6,8,17,0,9,0,3,0,0,19,4],"theta":["Romance","Musical","Adventure","Action","Fantasy","Comedy","Music","Mystery","Horror","Crime","History","Thriller","Family","Biography","Sport","Animation","Drama","Romance"],"type":"scatterpolar"},{"fill":"toself","name":"Nagesh Kukunoor","r":[3,0,0,1,1,4,0,1,0,2,0,1,0,0,1,0,9,3],"theta":["Romance","Musical","Adventure","Action","Fantasy","Comedy","Music","Mystery","Horror","Crime","History","Thriller","Family","Biography","Sport","Animation","Drama","Romance"],"type":"scatterpolar"},{"fill":"toself","name":"Yash Chopra","r":[12,5,0,7,0,1,1,1,0,2,1,3,3,0,0,0,21,12],"theta":["Romance","Musical","Adventure","Action","Fantasy","Comedy","Music","Mystery","Horror","Crime","History","Thriller","Family","Biography","Sport","Animation","Drama","Romance"],"type":"scatterpolar"},{"fill":"toself","name":"Hrishikesh Mukherjee","r":[12,7,0,0,0,14,0,1,0,0,0,0,6,0,0,0,25,12],"theta":["Romance","Musical","Adventure","Action","Fantasy","Comedy","Music","Mystery","Horror","Crime","History","Thriller","Family","Biography","Sport","Animation","Drama","Romance"],"type":"scatterpolar"},{"fill":"toself","name":"Anurag Kashyap","r":[2,0,1,5,0,2,0,3,1,8,0,3,0,0,1,1,11,2],"theta":["Romance","Musical","Adventure","Action","Fantasy","Comedy","Music","Mystery","Horror","Crime","History","Thriller","Family","Biography","Sport","Animation","Drama","Romance"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %%
import pandas as pd

# แปลงข้อมูล director_genre_count ให้เป็น DataFrame
genre_table = pd.DataFrame.from_dict(director_genre_count, orient='index')

# กรองเฉพาะผู้กำกับที่ต้องการเปรียบเทียบ
selected_director_table = genre_table.loc[selected_directors]

# แสดงผลตาราง
selected_director_table
# Out:
#                       Romance  Musical  Adventure  Action  Fantasy  Comedy  \
# Ram Gopal Varma             4        3          3      20        0       4
# Nagesh Kukunoor             3        0          0       1        1       4
# Yash Chopra                12        5          0       7        0       1
# Hrishikesh Mukherjee       12        7          0       0        0      14
# Anurag Kashyap              2        0          1       5        0       2
#
#                       Music  Mystery  Horror  Crime  History  Thriller  \
# Ram Gopal Varma           0        6       8     17        0         9
# Nagesh Kukunoor           0        1       0      2        0         1
# Yash Chopra               1        1       0      2        1         3
# Hrishikesh Mukherjee      0        1       0      0        0         0
# Anurag Kashyap            0        3       1      8        0         3
#
#                       Family  Biography  Sport  Animation  Drama
# Ram Gopal Varma            0          3      0          0     19
# Nagesh Kukunoor            0          0      1          0      9
# Yash Chopra                3          0      0          0     21
# Hrishikesh Mukherjee       6          0      0          0     25
# Anurag Kashyap             0          0      1          1     11
